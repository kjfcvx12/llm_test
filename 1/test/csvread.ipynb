# %%
import pandas as pd

# encoding='cp949'를 추가하여 다시 읽기
df = pd.read_csv('your_file.csv', encoding='cp949')

print(df)
# Out:
#      영유아성장종류코드 영유아성장종류코드명  성별코드 성별코드명  개월수구분코드 개월수구분코드명  영유아성장도표시작월  \
# 0            3       머리둘레     2    여아       69     69개월          69
# 1            3       머리둘레     2    여아       70     70개월          70
# 2            3       머리둘레     2    여아       71     71개월          71
# 3            3       머리둘레     2    여아       72     72개월          72
# 4            3       머리둘레     2    여아       73     73개월          73
# ..         ...        ...   ...   ...      ...      ...         ...
# 621          2          키     2    여아       66     66개월          66
# 622          2          키     2    여아       67     67개월          67
# 623          2          키     2    여아       68     68개월          68
# 624          2          키     2    여아       69     69개월          69
# 625          2          키     2    여아       70     70개월          70
#
#      영유아성장도표종료월  영유아성장도표L값  영유아성장도표M값  영유아성장도표S값
# 0            69    -1.2090    50.7060     0.0274
# 1            70    -1.3285    50.7575     0.0274
# ...
